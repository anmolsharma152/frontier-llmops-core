# %% [markdown]
# # QLoRA Fine-Tuning on Colab T4
#
# This notebook clones the repo, installs dependencies, and runs full QLoRA fine-tuning on a Mistral 7B model using a free T4 GPU.
#
# **Runtime**: Runtime → Change runtime type → T4 GPU

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

# %%
REPO_URL = "https://github.com/anmolsharma152/frontier-llmops-core.git"
NOTEBOOK_DIR = "/content/frontier-llmops-core"
DRIVE_OUTPUT = "/content/drive/MyDrive/peft-output"

if not os.path.exists(NOTEBOOK_DIR):
    # !git clone {REPO_URL} {NOTEBOOK_DIR}
# %cd {NOTEBOOK_DIR}

# %%
# !pip install -e 02_peft_tuning/
# !pip install wandb -q

# %%
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")

# %%
# !python 02_peft_tuning/scripts/main.py --config 02_peft_tuning/configs/defaults.yaml train

# %%
# !cp -r 02_peft_tuning/output/adapter {DRIVE_OUTPUT}
print(f"Adapter saved to {DRIVE_OUTPUT}")
